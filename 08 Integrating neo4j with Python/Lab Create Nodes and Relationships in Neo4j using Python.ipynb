# %%
# %pip install neo4j
# Out:
# Collecting neo4j
#   Downloading neo4j-6.0.3-py3-none-any.whl.metadata (5.2 kB)
# Collecting pytz (from neo4j)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Downloading neo4j-6.0.3-py3-none-any.whl (325 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Installing collected packages: pytz, neo4j
# Successfully installed neo4j-6.0.3 pytz-2025.2
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from neo4j import GraphDatabase

# %%
uri="bolt://localhost:11005"
username="neo4j"
password=""

# %%
driver=GraphDatabase.driver(uri, auth=(username, password))

# %%
def create_knowledge_graph(tx):
    query="""
    CREATE (p:Person {name:'John Doe', age:55})
    CREATE (c:Company {name:'Tech Corp', industry: 'Software'})
    CREATE (p)-[:WORKS_FOR]->(c)
    CREATE (p2:Person {name:'Jane Smith', age:28})
    CREATE (p2)-[:WORKS_FOR]->(c)
    CREATE (s:Skill {name:'Python'})
    CREATE (p)-[:HAS_SKILL]->(s)
    CREATE (p2)-[:HAS_SKILL]->(s)
    CREATE (p3:Person {name:'Mike Johnson', age:42})
    CREATE (p3)-[:KNOWS]->(p)
    RETURN 'Knowledge Graph Created'
    """
    tx.run(query)

# %%
def retrieve_knowledge_graph(tx):
    query="""
    MATCH (p:Person)-[r:WORKS_FOR]->(c:Company)
    RETURN p.name as Person, c.name as Company, p.age as Age
    """
    result = tx.run(query)
    return [record for record in result]

# %%
with driver.session() as session:
    session.execute_write(create_knowledge_graph)
    data = session.execute_read(retrieve_knowledge_graph)
# Out:
# Transaction failed and will be retried in 1.1798661933795955s (Couldn't connect to localhost:7687 (resolved to ('127.0.0.1:7687',)):
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused))
# Transaction failed and will be retried in 1.6034158013636237s (Couldn't connect to localhost:7687 (resolved to ('127.0.0.1:7687',)):
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused))
# Transaction failed and will be retried in 3.597181829189754s (Couldn't connect to localhost:7687 (resolved to ('127.0.0.1:7687',)):
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused))
# Transaction failed and will be retried in 9.370479868003626s (Couldn't connect to localhost:7687 (resolved to ('127.0.0.1:7687',)):
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused))
# Transaction failed and will be retried in 17.31117163273828s (Couldn't connect to localhost:7687 (resolved to ('127.0.0.1:7687',)):
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused))
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_async_compat/network/_bolt_socket.py:498, in BoltSocketBase._connect_secure(cls, resolved_address, timeout, keep_alive, ssl_context)
#     497 log.debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 498 s.connect(resolved_address)
#     499 s.settimeout(t)
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_bolt_socket.py:329, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     328 try:
# --> 329     s = cls._connect_secure(
#     330         resolved_address, tcp_timeout, keep_alive, ssl_context
#     331     )
#     332     agreed_version = s._handshake(resolved_address, deadline)
#
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_async_compat/network/_bolt_socket.py:521, in BoltSocketBase._connect_secure(cls, resolved_address, timeout, keep_alive, ssl_context)
#     520 if isinstance(error, OSError):
# --> 521     raise ServiceUnavailable(
#     522         "Failed to establish connection to "
#     523         f"{resolved_address!r} (reason {error})"
#     524     ) from error
#     525 raise
#
# ServiceUnavailable: Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused)
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[20], line 2
#       1 with driver.session() as session:
# ----> 2     session.execute_write(create_knowledge_graph)
#       3     data = session.execute_read(retrieve_knowledge_graph)
#
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_sync/work/session.py:720, in Session.execute_write(self, transaction_function, *args, **kwargs)
#     667 @NonConcurrentMethodChecker._non_concurrent_method
#     668 def execute_write(
#     669     self,
#    (...)    674     **kwargs: _P.kwargs,
#     675 ) -> _R:
#     676     """
#     677     Execute a unit of work in a managed write transaction.
#     678
#    (...)    718     .. versionadded:: 5.0
#     719     """  # noqa: E501 example code isn't too long
# --> 720     return self._run_transaction(
#     721         WRITE_ACCESS,
#     722         TelemetryAPI.TX_FUNC,
#     723         transaction_function,
#     724         args,
#     725         kwargs,
#     726     )
#
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_sync/work/session.py:584, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     579         raise
#     581 if errors:
#     582     # TODO: 7.0 - when Python 3.11+ is the minimum,
#     583     #             use exception groups
# --> 584     raise errors[-1]
#     585 else:
#     586     raise ServiceUnavailable("Transaction failed")
#
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_sync/work/session.py:532, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     530 while True:
#     531     try:
# --> 532         self._open_transaction(
#     533             tx_cls=ManagedTransaction,
#     534             api=None if telemetry_sent else api,
#     535             access_mode=access_mode,
#     536             metadata=metadata,
#     537             timeout=timeout,
#     538             api_success_cb=api_success_cb,
#     539         )
#     540         assert isinstance(self._transaction, ManagedTransaction)
#     541         tx = self._transaction
#
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_sync/work/session.py:398, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     388 def _open_transaction(
#     389     self,
#     390     *,
#    (...)    396     api_success_cb: t.Callable[[dict], None] | None = None,
#     397 ) -> None:
# --> 398     self._connect(access_mode=access_mode)
#     399     assert self._connection is not None
#     400     if api is not None:
#
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_sync/work/session.py:126, in Session._connect(self, access_mode, **acquire_kwargs)
#     124     access_mode = self._config.default_access_mode
#     125 try:
# --> 126     super()._connect(
#     127         access_mode, auth=self._config.auth, **acquire_kwargs
#     128     )
#     129 except asyncio.CancelledError:
#     130     self._handle_cancellation(message="_connect")
#
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_sync/work/workspace.py:181, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     171 acquire_kwargs_ = {
#     172     "access_mode": access_mode,
#     173     "timeout": acquisition_deadline,
#    (...)    178     "database_callback": self._make_db_resolution_callback(),
#     179 }
#     180 acquire_kwargs_.update(acquire_kwargs)
# --> 181 self._connection = self._pool.acquire(**acquire_kwargs_)
#     182 if (
#     183     target_db.guessed
#     184     and not self._pinned_database
#    (...)    188     # support SSR.
#     189     # => we need to fall back to explicit home database resolution
#     190     log.debug(
#     191         "[#0000]  _: <WORKSPACE> detected ssr support race; "
#     192         "falling back to explicit home database resolution",
#     193     )
#
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_pool.py:678, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout, unprepared, database_callback)
#     671 deadline = acquisition_timeout_to_deadline(timeout)
#     672 log.debug(
#     673     "[#0000]  _: <POOL> acquire direct connection, "
#     674     "access_mode=%r, database=%r",
#     675     access_mode,
#     676     database,
#     677 )
# --> 678 return self._acquire(
#     679     self.address, auth, deadline, liveness_check_timeout, unprepared
#     680 )
#
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_pool.py:418, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout, unprepared)
#     413             raise ConnectionAcquisitionTimeoutError(
#     414                 "failed to obtain a connection from the pool within "
#     415                 f"{deadline.original_timeout!r}s (timeout)"
#     416             )
#     417 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 418 return connection_creator()
#
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_pool.py:231, in IOPool._acquire_new_later.<locals>.connection_creator()
#     229 try:
#     230     try:
# --> 231         connection = self.opener(
#     232             address, auth or self.pool_config.auth, deadline
#     233         )
#     234     except ServiceUnavailable:
#     235         self.deactivate(address)
#
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_pool.py:638, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     637 def opener(addr, auth_manager, deadline):
# --> 638     return Bolt.open(
#     639         addr,
#     640         auth_manager=auth_manager,
#     641         deadline=deadline,
#     642         routing_context=None,
#     643         pool_config=pool_config,
#     644     )
#
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_bolt.py:367, in Bolt.open(address, auth_manager, deadline, routing_context, pool_config)
#     364 if deadline is None:
#     365     deadline = Deadline(None)
# --> 367 s, protocol_version = BoltSocket.connect(
#     368     address,
#     369     tcp_timeout=pool_config.connection_timeout,
#     370     deadline=deadline,
#     371     custom_resolver=pool_config.resolver,
#     372     ssl_context=pool_config.get_ssl_context(),
#     373     keep_alive=pool_config.keep_alive,
#     374 )
#     376 pool_config.protocol_version = protocol_version
#     377 protocol_handlers = Bolt.protocol_handlers
#
# File /media/francis/Data2/Source/Udemy/udemy-handson-neo4j-knowledge-graph/.venv/lib/python3.13/site-packages/neo4j/_sync/io/_bolt_socket.py:376, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     374 else:
#     375     error_strs = "\n".join(map(str, errors))
# --> 376     raise ServiceUnavailable(
#     377         f"Couldn't connect to {address} (resolved to {address_strs}):"
#     378         f"\n{error_strs}"
#     379     ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to localhost:7687 (resolved to ('127.0.0.1:7687',)):
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused)

# %%
print(session)
# Out:
# <neo4j._sync.work.session.Session object at 0x7e53a96ecad0>

# %%
for record in data:
    print(f"{record['Person']} (Age: {record['Age']}) works for {record['Company']}")
